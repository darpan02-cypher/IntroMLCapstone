# %% [markdown]
# # 02_preprocessing_template
#
# Template for preprocessing and feature extraction. Use `src/features.py` helper functions.

# %%
import sys
sys.path.append('../src')
from features import rolling_features, compute_hrv_metrics
import pandas as pd

print('Template: adapt to your dataset format')

# Example usage for a 1D signal series (pseudo-code):
# signal = pd.Series(...)  # your EDA or HR signal
# feats = rolling_features(signal, window=30, fs=4)
# print(feats.head())
